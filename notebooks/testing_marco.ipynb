# %%
# Cell 1: Setup and imports
import sys
from pathlib import Path
# %load_ext autoreload
# %autoreload 2

# Add repo root to path
repo_root = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(repo_root))

from src.utils import log_timing

from src.transformers import convert_to_json
import json

# Cell 2: Test convert_to_json
xml_path = repo_root / "xml_input" / "YHC_CL_JO_2-whole-tree.xml"
output_dir = repo_root / "data" / "test_outputs"
output_dir.mkdir(parents=True, exist_ok=True)

# Call the function
with log_timing("Conversion completed in"):
    records = convert_to_json(
        xml_path=str(xml_path),
        output_dir=str(output_dir),
        remove_empty_fields=True
    )

print(f"Converted {len(records)} records")
print(f"Sample record keys: {list(records.keys())[:5]}")

records['0126c4bf-6787-404e-8ba6-e2223d55c120']
# Out:
# length of root records: 320
# 320 records processed from the XML file.
# Converted 320 records
# Sample record keys: ['375bbc41-06b6-4e78-b836-31c5357a2391', '0126c4bf-6787-404e-8ba6-e2223d55c120', 'c31ee753-1fbd-49ba-8e7f-0c550eba5d9b', 'c0641cac-ae8a-48b4-8896-fbfb7ef6a7f2', '11a81b42-cac3-4221-a420-e314fc9abb94']
# {'record': {'iaid': '0126c4bf-6787-404e-8ba6-e2223d55c120',
#   'citableReference': 'YHC/CL/JO/2/42',
#   'parentId': '96d4a7b8-1a7f-4383-9b7f-7d15deea7e94',
#   'catalogueId': 26760301,
#   'catalogueLevel': 9,
#   'coveringFromDate': 17720121,
#   'coveringToDate': 17721117,
#   'chargeType': 1,
#   'coveringDates': '21 Jan 1772-17 Nov 1772',
#   'closureStatus': 'O',
#   'creatorName': [{'startDate': 0, 'endDate': 0}],
#   'digitised': False,
#   'formerReferencePro': 'CJ Volume 33 Part 2',
#   'heldBy': [{'xReferenceId': 'A13530124',
#     'xReferenceCode': '66',
#     'xReferenceName': 'The National Archives, Kew'}],
#   'legalStatus': 'Not Public Record(s)',
#   'physicalDescriptionExtent': '1',
#   'physicalDescriptionForm': ' volume',
#   'referencePart': '42',
#   'source': 'PA',
#   'title': 'Printed Journals of the House of Commons, 1772-1772'}}
